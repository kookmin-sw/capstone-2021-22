# %%
import tensorflow as tf
from tensorflow import keras
import os
import re
import numpy as np
import shutil
import random
import matplotlib.pyplot as plt

# %%
tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)
# Out:
# WARNING:tensorflow:From <ipython-input-2-ebb74ce83619>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %% [markdown]
# # 데이터 준비

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq "/content/drive/MyDrive/이게뭐약/sampleimgdata/규리_sampleimg_파일명으로class_100개/sampleimg_nobackground.zip"

# %%
# !unzip -qq "/content/drive/MyDrive/이게뭐약/sampleimgdata/배경제거실사콜라주데이터확대50.zip"

# %%
path="./sampleimg"
file_list = os.listdir(path)
for filename in file_list:
  src = '/content/sampleimg/'
  dir = '/content/sampleimg_nobackground/'
  shutil.move(src + filename, dir + filename)

# %%
# !unzip -qq "/content/drive/MyDrive/이게뭐약/sampleimgdata/배경제거실사콜라주데이터확대50_2.zip"

# %%
path="./sampleimg"
file_list = os.listdir(path)
for filename in file_list:
  src = '/content/sampleimg/'
  dir = '/content/sampleimg_nobackground/'
  shutil.move(src + filename, dir + filename)

# %%
data_dir = '/content/sampleimg_nobackground'
print(data_dir)
# Out:
# /content/sampleimg_nobackground

# %%
listdir = os.listdir(data_dir)
print(listdir)
# Out:
# ['가나모티에스알정15밀리그램_0_5169.jpg', '네비로스타정1.25-5밀리그램_0_6342.jpg', '알마겔정_0_6094.jpg', '덴타돌플러스정_0_7655.jpg', '로타젯정10-5밀리그램_0_4911.jpg', '본스칼엠정_0_6071.jpg', '알기온정_0_2090.jpg', '로바이지정10-10밀리그램_0_4092.jpg', '아발탄에이플러스정5-160-20밀리그램_0_7541.jpg', '알픽스정5밀리그램_0_7604.jpg', '아발탄에이플러스정5-160-20밀리그램_0_6434.jpg', '올메로바정20-10밀리그램_0_7993.jpg', '로젯탐정10-5밀리그램_0_6211.jpg', '푸푸에프연질캡슐_0_4575.jpg', '엔빅사정2.5밀리그램_0_5664.jpg', '다우제큐정_0_7714.jpg', '리멘시아연질캡슐120밀리그램_0_6541.jpg', '다우제큐정_0_422.jpg', '발사로브정20-80밀리그램_0_2914.jpg', '에베로즈정5밀리그램_0_1296.jpg', '아바트리정5-80-20밀리그램_0_5468.jpg', '올르메틴정20-5밀리그램_0_2808.jpg', '엔시트라세미정_0_972.jpg', '삼티스캡슐_0_614.jpg', '헤토마신캡슐_0_6130.jpg', '헤토마신캡슐_0_173.jpg', '인브로정_0_744.jpg', '케이모틴씨알정15밀리그램_0_6174.jpg', '뉴라조신정2밀리그램_0_5151.jpg', '에제로정10-20밀리그램_0_3164.jpg', '로바르탄정10-160밀리그램_0_1068.jpg', '알피나정_0_2315.jpg', '레가바정150밀리그램_0_8097.jpg', '펜스톱연질캡슐_0_5035.j